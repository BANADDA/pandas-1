# %% [markdown]
# <a href="https://colab.research.google.com/github/BANADDA/pandas-1/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90aa0f94-381b-4555-a7c8-70f29e2ae3ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90aa0f94-381b-4555-a7c8-70f29e2ae3ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CassavaImagelinks1.xlsx to CassavaImagelinks1.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel('CassavaImagelinks1.xlsx')

# %%
df.head()
# Out:
#                                         _URI _CREATOR_URI_USER  \
# 0  uuid:793b08fd-4d24-42a0-835c-fede2e71ec14     anonymousUser
# 1  uuid:e235fa16-536d-4e2b-a463-95d32407f852     anonymousUser
# 2  uuid:4806eecb-f8a6-46ae-b34c-58a5e02e8cee     anonymousUser
# 3  uuid:0ff8ad92-8d31-45e9-8b16-7010939e5f96     anonymousUser
# 4  uuid:47ed731b-98e7-426e-a2f0-138b1e0ddb48     anonymousUser
#
#            _CREATION_DATE _LAST_UPDATE_URI_USER       _LAST_UPDATE_DATE  \
# 0 2019-09-23 00:37:16.450                   NaN 2019-09-23 00:37:16.450
# 1 2019-09-23 13:08:04.458                   NaN 2019-09-23 13:08:04.458
# 2 2019-09-23 13:08:21.196                   NaN 2019-09-23 13:08:21.196
# 3 2019-09-23 13:08:26.384                   NaN 2019-09-23 13:08:26.384
# 4 2019-09-23 13:08:37.028                   NaN 2019-09-23 13:08:37.028
#
#    _MODEL_VERSION  _UI_VERSION  _IS_COMPLETE        _SUBMISSION_DATE  \
# 0             NaN          NaN             1 2019-09-23 00:37:16.443
# ...

# %%
df.describe() # Giving a descriptive statistics summary of a given dataset.
# Out:
#        _MODEL_VERSION  _UI_VERSION   _IS_COMPLETE  \
# count             0.0          0.0  135607.000000
# mean              NaN          NaN       0.736739
# std               NaN          NaN       0.440404
# min               NaN          NaN       0.000000
# 25%               NaN          NaN       0.000000
# 50%               NaN          NaN       1.000000
# 75%               NaN          NaN       1.000000
# max               NaN          NaN       1.000000
#
#        CASSAVA_DATA_CASSAVA_IMAGE_GPS_ALT  CASSAVA_DATA_PHONE_ID  \
# count                       135605.000000           1.355360e+05
# mean                           936.943616           3.578415e+14
# std                            400.810035           1.785199e+12
# min                          -1334.600000           3.516321e+14
# 25%                           1064.400000           3.582461e+14
# 50%                           1099.000000           3.582461e+14
# ...

# %%
df['CASSAVA_DATA_CASSAVA_COMMENT'].mode() # Most occurent topic in cassava comment
# Out:
# 0    Cbb
# dtype: object

# %%
import pylab as pl
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
df['_SUBMISSION_DATE'] = pd.to_datetime(df['_SUBMISSION_DATE'])
df.sort_values('_SUBMISSION_DATE', inplace = True)
df.hist(column = '_SUBMISSION_DATE', edgecolor = "black", color = 'khaki')
pl.suptitle("Frequency of Data Amounts collected over Time")
plt.xlabel("SUBMISSION DATE", labelpad = 20, weight = 'bold', size = 12)
plt.ylabel("FREQUENCY", labelpad = 20, weight = 'bold', size = 12)
plt.figure(figsize = [20, 100])

# %%
y = df['CASSAVA_DATA_CASSAVA_IMAGE_CLASS']
x = df['_SUBMISSION_DATE']
plt.plot(x, y)
plt.show()
